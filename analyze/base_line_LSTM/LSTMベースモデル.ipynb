# %% [markdown]
# # ベースモデル（LSTM）
# ## 特徴量：y, client, close, price_am, price_pm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
sns.set()

from datetime import date
import holidays
import datetime as dt
import japanize_matplotlib

# %%
data = pd.read_csv("./train.csv")
data.head()
# Out:
#      datetime   y  client  close  price_am  price_pm
# 0  2010-07-01  17       0      0        -1        -1
# 1  2010-07-02  18       0      0        -1        -1
# 2  2010-07-03  20       0      0        -1        -1
# 3  2010-07-04  20       0      0        -1        -1
# 4  2010-07-05  14       0      0        -1        -1

# %%
# 0	datetime	日時（YYYY-MM-DD）	文字列
# 1	y	引越し数	数値：整数
# 2	client	法人が絡む特殊な引越し日フラグ	数値：整数（0,1）
# 3	close	休業日	数値：整数（0,1）
# 4	price_am	午前の料金区分（-1は欠損を表す。5が最も料金が高い）	数値：整数（-1,0,1,2,3,4,5）
# 5	price_pm	午後の料金区分（-1は欠損を表す。5が最も料金が高い）	数値：整数（-1,0,1,2,3,4,5）

# %% [markdown]
# ##　内井入力

# %%
from datetime import date
import holidays
holidays_d = []
for i in np.arange(0,len(data)):
    a= data["datetime"][i] in holidays.JP()
    holidays_d.append(a)
data["holidays"] = holidays_d
data = data.replace({False:0, True:1})

# %% [markdown]
# ##　以下　寺澤さん入力

# %%
#datetimeを日付型に変換
data['datetime'] = pd.to_datetime(data['datetime'], format='%Y-%m-%d')

# %%
data['year'] = data['datetime'].dt.year
data['month'] = data['datetime'].dt.month
data['day'] = data['datetime'].dt.day
data['Weekday'] = data['datetime'].dt.strftime('%A')

# %% [markdown]
# ## モデル実装

# %%
# !pip3 install keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import pandas as pd
# Out:
# Requirement already satisfied: keras in c:\users\ayumi\anaconda3\lib\site-packages (2.10.0)

# %% [markdown]
# ### 学習データの作成

# %%
# 2011年４月１日以降のデータを対象にしてベースモデルを作成する
data = data[data["datetime"] >= "2011-04-01" ]

# %%
#データセットを作る関数
look_back = 30


def make_dataset(raw_data, look_back=30):
    _x = []
    _y = []

    for i in range(len(raw_data) - look_back):
        _x.append(raw_data[i : i + look_back])
        _y.append(raw_data[i + look_back])
    _x = np.array(_x).reshape(len(_x), look_back, 1)
    _y = np.array(_y).reshape(len(_y), 1)

    return _x, _y

# %%
X_y, y_y = make_dataset(data['y'].values, look_back=look_back)
X_client, y_client = make_dataset(data['client'].values, look_back=look_back)
X_close, y_close = make_dataset(data['close'].values, look_back=look_back)
X_price_am, y_price_am = make_dataset(data['price_am'].values, look_back=look_back)
X_price_pm, y_price_pm = make_dataset(data['price_pm'].values, look_back=look_back)

X_con = np.concatenate([X_y, X_client, X_close, X_price_am, X_price_pm], axis=2)

# %%
X = X_con
y = y_y

sample_size = len(data) - look_back
past_size = int(sample_size * 0.8) #サンプルデータのうち、8割を学習データ、2割を検証用データとする
future_size = sample_size - past_size + 1

#データを訓練用と検証用に分割
X_past = X[:past_size]
X_future = X[past_size-1:]
y_past = y[:past_size]
y_future = y[past_size-1:]

#訓練用データを定義
X_train = X_past
y_train = y_past

# %%
X_train.shape
# Out:
# (1437, 30, 5)

# %% [markdown]
# ## モデル構築

# %%
#　モデル構築

# 1つの学習データのStep数（今回は30）

lengh_of_sequence = X_train.shape[1] 
out_nerons = 1
n_hidden = 50 #隠れ層のユニット数（数が多いほど学習モデルの複雑さが増加）
loss = tf.keras.losses.MeanAbsoluteError() # 最小絶対値誤差

model = Sequential()
model.add(LSTM(n_hidden,
               batch_input_shape=(None,lengh_of_sequence , 5) ,  #入力データの次元数
               return_sequences=False)) # バッチ型で学習するならここはFalse

model.add(Dense(out_nerons)) # 30のデータから１つの値を予測したいので１となる
model.add(Activation("linear")) # 活性化関数を指示

# compileで誤差関数：最小二乗誤差、最適化手法：Adamを用いるように定義
optimizer = Adam(lr=0.01)
model.compile(loss=loss , optimizer=optimizer)
# Out:
# c:\Users\ayumi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=20)
model.fit(X_train, y_train,
          batch_size=100,
          epochs=100, #繰り返し回数
          )
# Out:
# Epoch 1/100
# 15/15 [==============================] - 3s 32ms/step - loss: 30.9013
# Epoch 2/100
# 15/15 [==============================] - 0s 30ms/step - loss: 24.1225
# Epoch 3/100
# 15/15 [==============================] - 0s 29ms/step - loss: 18.2447
# Epoch 4/100
# 15/15 [==============================] - 0s 29ms/step - loss: 14.3887
# Epoch 5/100
# 15/15 [==============================] - 0s 28ms/step - loss: 11.7582
# Epoch 6/100
# 15/15 [==============================] - 0s 29ms/step - loss: 10.0205
# Epoch 7/100
# 15/15 [==============================] - 0s 29ms/step - loss: 8.9270
# Epoch 8/100
# 15/15 [==============================] - 0s 30ms/step - loss: 8.2957
# Epoch 9/100
# 15/15 [==============================] - 0s 29ms/step - loss: 8.2901
# Epoch 10/100
# 15/15 [==============================] - 0s 29ms/step - loss: 7.8356
# Epoch 11/100
# 15/15 [==============================] - 0s 29ms/step - loss: 7.5774
# Epoch 12/100
# 15/15 [==============================] - 0s 29ms/step - loss: 7.6586
# Epoch 13/100
# 15/15 [==============================] - 1s 40ms/step - loss: 7.4762
# Epoch 14/100
# 15/15 [==============================] - 0s 31ms/step - loss: 7.3019
# Epoch 15/100
# 15/15 [==============================] - 1s 41ms/step - loss: 7.1580
# Epoch 16/100
# 15/15 [==============================] - 0s 30ms/step - loss: 7.0570
# Epoch 17/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.9601
# Epoch 18/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.9743
# Epoch 19/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.9865
# Epoch 20/100
# 15/15 [==============================] - 0s 32ms/step - loss: 6.9074
# Epoch 21/100
# 15/15 [==============================] - 0s 31ms/step - loss: 6.9189
# Epoch 22/100
# 15/15 [==============================] - 1s 34ms/step - loss: 6.7833
# Epoch 23/100
# 15/15 [==============================] - 0s 31ms/step - loss: 6.7042
# Epoch 24/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.8952
# Epoch 25/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.7647
# Epoch 26/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.8730
# Epoch 27/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.7731
# Epoch 28/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.8322
# Epoch 29/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.7155
# Epoch 30/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.7848
# Epoch 31/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.7043
# Epoch 32/100
# 15/15 [==============================] - 0s 33ms/step - loss: 6.5079
# Epoch 33/100
# 15/15 [==============================] - 0s 32ms/step - loss: 6.4620
# Epoch 34/100
# 15/15 [==============================] - 1s 34ms/step - loss: 6.3400
# Epoch 35/100
# 15/15 [==============================] - 0s 33ms/step - loss: 6.3943
# Epoch 36/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.3534
# Epoch 37/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.3894
# Epoch 38/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.3082
# Epoch 39/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.2060
# Epoch 40/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.1558
# Epoch 41/100
# 15/15 [==============================] - 0s 29ms/step - loss: 6.1249
# Epoch 42/100
# 15/15 [==============================] - 0s 34ms/step - loss: 6.1035
# Epoch 43/100
# 15/15 [==============================] - 0s 31ms/step - loss: 6.0969
# Epoch 44/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.9819
# Epoch 45/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.9830
# Epoch 46/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.9482
# Epoch 47/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.1126
# Epoch 48/100
# 15/15 [==============================] - 0s 30ms/step - loss: 6.0395
# Epoch 49/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.9514
# Epoch 50/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.8458
# Epoch 51/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.8380
# Epoch 52/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.8519
# Epoch 53/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.7602
# Epoch 54/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.7446
# Epoch 55/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.7763
# Epoch 56/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.7467
# Epoch 57/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.6508
# Epoch 58/100
# 15/15 [==============================] - 1s 37ms/step - loss: 5.6729
# Epoch 59/100
# 15/15 [==============================] - 1s 34ms/step - loss: 5.6673
# Epoch 60/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.7267
# Epoch 61/100
# 15/15 [==============================] - 1s 35ms/step - loss: 5.6712
# Epoch 62/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.6107
# Epoch 63/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.6208
# Epoch 64/100
# 15/15 [==============================] - 1s 34ms/step - loss: 5.5850
# Epoch 65/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.4961
# Epoch 66/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.5871
# Epoch 67/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.5534
# Epoch 68/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.5746
# Epoch 69/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.6476
# Epoch 70/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.4795
# Epoch 71/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.4666
# Epoch 72/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.4665
# Epoch 73/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.4827
# Epoch 74/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.4223
# Epoch 75/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.4708
# Epoch 76/100
# 15/15 [==============================] - 0s 32ms/step - loss: 5.4529
# Epoch 77/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.4720
# Epoch 78/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.5181
# Epoch 79/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.4911
# Epoch 80/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.4200
# Epoch 81/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.3933
# Epoch 82/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.2781
# Epoch 83/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.3480
# Epoch 84/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.3016
# Epoch 85/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.3284
# Epoch 86/100
# 15/15 [==============================] - 0s 33ms/step - loss: 5.3939
# Epoch 87/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.2571
# Epoch 88/100
# 15/15 [==============================] - 0s 31ms/step - loss: 5.2211
# Epoch 89/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.2752
# Epoch 90/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.2049
# Epoch 91/100
# 15/15 [==============================] - 0s 32ms/step - loss: 5.2135
# Epoch 92/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.1549
# Epoch 93/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.2378
# Epoch 94/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.1883
# Epoch 95/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.1906
# Epoch 96/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.2607
# Epoch 97/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.2558
# Epoch 98/100
# 15/15 [==============================] - 0s 30ms/step - loss: 5.1513
# Epoch 99/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.1770
# Epoch 100/100
# 15/15 [==============================] - 0s 29ms/step - loss: 5.0970

# %%
# 予測
predictions = model.predict(X_past)
future_predictions = model.predict(X_future)
# Out:
# 45/45 [==============================] - 1s 6ms/step
# 12/12 [==============================] - 0s 6ms/step

# %%
#可視化
plt.figure(figsize=(18,9))
plt.plot(data['datetime'][look_back:], y, color='b', label='true_y', alpha = 0.5)
plt.plot(data['datetime'][look_back:look_back + past_size], predictions, color='r', linestyle='dashed', label='predictions')
plt.plot(data['datetime'][-future_size:], future_predictions, color='g', linestyle='dashed', label='future_predictions')
plt.legend()
plt.show()

# %% [markdown]
# 赤色が訓練データに対する予測のプロット、\
# 緑色が検証データに対する予測のプロットです。\
# 赤色は割と特徴捉えられているのに対して、緑色（未知のデータ）に対しては、大局的な変化は捉えられていますが、局所的な変化は捉えられていないようです。
